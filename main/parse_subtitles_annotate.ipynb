# %%
import json
import pandas as pd
import re

from pathlib import Path
from typing import List, Dict

# %% [markdown]
# ### Extract HTML Scripts

# %%
import json
import re

from pathlib import Path
from bs4 import BeautifulSoup  # type: ignore[import-not-found]
from typing import Any, Dict, List, cast

# %%
def parse_html_script_new(html_path: Path) -> Dict[str, Any]:
    with open(html_path, "r", encoding="utf-8") as f:
        content = f.read()

    soup = BeautifulSoup(content, "html.parser")

    title_tag = soup.find("title")
    title = title_tag.get_text() if title_tag else ""

    episode_num = html_path.stem
    scenes = []
    current_scene = {"scene_description": "Episode dialogue", "dialogue": []}

    # Skip terms in header/footer metadata
    skip_keywords = [
        "written", "transcribed", "originally", "minor",
        "adjustment", "story", "teleplay", "directed"
    ]
    max_speaker_len = 30

    def extract_multiple_speakers(text: str) -> List[Dict[str, str]]:
        """Extract all SPEAKER: dialogue pairs from a single line."""
        results = []
        pattern = re.compile(r"([A-Za-z][A-Za-z\s.'()/-]{0,30}):")

        matches = list(pattern.finditer(text))
        for i, m in enumerate(matches):
            speaker = m.group(1).strip()
            start = m.end()
            end = matches[i + 1].start() if i + 1 < len(matches) else len(text)
            dialogue = text[start:end].strip()

            # Clean + validate
            if any(k in speaker.lower() for k in skip_keywords):
                continue
            if len(speaker) > max_speaker_len:
                continue
            dialogue = re.sub(r"\s+", " ", dialogue).strip()
            if dialogue:
                results.append({"speaker": speaker.upper(), "text": dialogue})
        return results

    for p in soup.find_all("p"):
        raw = p.get_text(" ", strip=True)
        if not raw:
            continue

        # Scene detection like [Scene: ...]
        if raw.startswith("[Scene:") or raw.startswith("[Opening") or raw.startswith("[Closing"):
            if current_scene["dialogue"]:
                scenes.append(current_scene)
            current_scene = {"scene_description": raw, "dialogue": []}
            continue

        # Extract all speaker/dialogue segments in this paragraph
        pairs = extract_multiple_speakers(raw)
        if pairs:
            current_scene["dialogue"].extend(pairs)

    if current_scene["dialogue"]:
        scenes.append(current_scene)

    return {"episode": episode_num, "title": title, "scenes": scenes}

# %%
def convert_all_html_scripts(input_dir: Path, output_dir: Path) -> None:
    """Convert all HTML scripts to JSON format.

    Args:
        input_dir: Directory containing HTML script files.
        output_dir: Directory to save JSON files.
    """
    print(f"\n{'='*80}")
    print("Converting HTML Scripts to JSON (Edersoncorbari)")
    print(f"{'='*80}\n")

    output_dir.mkdir(parents=True, exist_ok=True)

    html_files = sorted(input_dir.glob("*.html"))

    episode_files = [f for f in html_files if re.match(r"^\d{4}", f.stem)]
    
    print(f"Found {len(episode_files)} episode scripts")

    for i, html_file in enumerate(episode_files, 1):
        try:
            if i % 10 == 0 or i == len(episode_files):
                print(f"Progress: {i}/{len(episode_files)}", end="\r")

            data = parse_html_script_new(html_file)

            output_file = output_dir / f"{html_file.stem}.json"
            with open(output_file, "w", encoding="utf-8") as f:
                json.dump(data, f, indent=2, ensure_ascii=False)

        except Exception as e:
            print(f"\nError processing {html_file.name}: {e}")

    print(f"\n\nHTML scripts converted: {len(episode_files)} files")
    print(f"Output directory: {output_dir}")

# %%
# data_dir = Path("./data")
html_input_dir = Path("./edersoncorbari_subtitles_html/bad")
html_output_dir = Path("./edersoncorbari_new_annotated")

if html_input_dir.exists():
    convert_all_html_scripts(html_input_dir, html_output_dir)
# Out:
# ================================================================================
# Converting HTML Scripts to JSON (Edersoncorbari)
# ================================================================================
#
# Found 1 episode scripts
# Progress: 1/1
#
# HTML scripts converted: 1 files
# Output directory: edersoncorbari_new_annotated

# %% [markdown]
# ### Parse Subtitles from Edersoncobari

# %%
def add_new_annotations(data: dict):
    episode = data.get("episode")
    scenes = data.get("scenes", [])
    bad_subject_strings = ["ALL", " AND ", ")", "(", "GUYS", "GIRLS", "BOTH", "ITNERCOM", " TO "]
    counter = 0
    for idx, scene in enumerate(scenes):
        ### Extract all unique subjects
        speakers_seen = []
        for turn in scene.get("dialogue", []):
            sp = turn.get("speaker")
            if isinstance(sp, str):
                sp_clean = sp.strip()
                if sp_clean and sp_clean not in speakers_seen:
                        if not any(s in sp_clean for s in bad_subject_strings):
                            speakers_seen.append(sp_clean)
        
        ### Extract the location from scene description
        scene_description = scene.get("scene_description")
        print(scene_description)
        if not isinstance(scene_description, str):
            return ""
        else:
            m = re.search(r"\[Scene\s*[:\-]?\s*([^\],]+)", scene_description, flags=re.I)
            try:
                location = m.group(1).strip()
            except AttributeError:
                location = ""
        if scene.get("clip_start", "") != "":
            scene["context_label"] = f"{episode}_scene_{str(counter).zfill(3)}_{location}"
            counter += 1
        else:
            scene["context_label"] = ""
        scene["location"] = location
        scene["subjects"] = list(set(speakers_seen))
        scene["event_description"] = scene_description
        if scene.get("clip_start", "") == "":
            scene["clip_start"] = ""
        if scene.get("clip_end", "") == "":
            scene["clip_end"] = ""
        if scene.get("srt_start", 0) == 0:
            scene["srt_start"] = ""
        if scene.get("srt_end", 0) == 0:
            scene["srt_end"] = ""
        # scene["srt_start"] = scene["clip_start"]
        # scene["srt_end"] = scene["clip_end"]
        # scene["clip_end"] = ""

    return data, episode

# %%
subs_dir = Path("./subtitles/edersoncorbari_new_annotated/season_03")
output_dir = Path("./subtitles/annotated_tuples/season_03")

json_subs = []
for file in sorted(subs_dir.rglob("*.json")):
    if 'bad' not in str(file):
        with open(file) as f:
            subs = json.load(f)
            json_subs.append(subs)
            f.close()                     

output_dir.mkdir(exist_ok=True)
for subs_data in json_subs:
    annotated_subs_data, episode = add_new_annotations(subs_data)
    save_dir = output_dir / f"{episode}.json"
    with open(save_dir, "w") as f:
        json.dump(annotated_subs_data, f, indent=4)
# Out:
# Episode dialogue
# [Scene: Rachel and Monica's, Phoebe, Ross, and Rachel are eating breakfast.]
# [Scene: Chandler and Joey's, Joey is coming in from the bedroom]
# [Scene: Rachel and Monica's, Monica is entering from the bathroom.]
# [Scene: Ross's bedroom, Ross is working and Rachel is reading a book in bed]
# [Scene: Central Perk, Phoebe and Rachel are there]
# [Scene: Chandler and Joey's, Joey is watching Wheel of Fortune, the puzzle is showing
# _oun_ Rush_ore.]
# [Scene: Monica and Rachel's, Rachel and Ross are entering]
# [Scene: Monica's bedroom, Phoebe is trying to relax her.]
# [Scene: Chandler and Joey's]
# [Scene: Central Perk, Rachel and Monica are entering]
# [Scene: Chandler and Joey's, Joey and Janice are returning from their DAY OF FUN!]
# [Scene: Rachel and Monica's, Monica is watching the Civil War videos]
# [Scene: Ross's bedroom, Ross is humming the Star Wars theme. Rachel enters, with her
# hair done up like Princess Leia's, and wearing a belly dancer's outfit, to simulate the
# gold bikini thing.]
# [Scene: Chandler and Joey's, Chandler is sitting reading a book and hears the bed in
# Joey's room creaking, and does a 'Oh no, not again' look on his face.]
# [Scene: Monica and Rachel's, Ross and Rachel are entering]
# [Scene: Street, Phoebe is being followed by some guy, as they pass a flower vendor.
# Phoebe turns around and the guy quickly picks up some flowers and continues following
# her.]
# [Scene: Monica and Rachel's, Ross and Rachel are entering]
# [Scene: Central Perk, Joey is putting jam on his muffin, lots of jam]
# [Scene: Chandler's bedroom, Janice and him are cuddling]
# [Scene: Central Perk, Malcom is giving Phoebe all of his spy stuff]
# [Scene: Monica and Rachel's, Joey is eating jam straight out of the jar, and Chandler
# is staring at him in amazement. Joey offers him some.]
# [Scene: Central Perk]
# [Scene: Subway station, Phoebe is following Malcom by finding behind the pillars until
# she comes up to one with a wire mesh garbage can next to it. Malcom stops and starts
# walking the other way and passes Phoebe, who quick tries to hide behind the garbage can.
# But, Malcom sees her.]
# [Scene: Monica and Rachel's, Joey is entering]
# [Scene: Monica and Rachel's, Joey is finishing off the last of the jam]
# [Scene: Monica and Rachel's: everyone is there and they are watching an
# info-mercial that stars Joey.]
# [Scene: Central Perk, Chandler, Monica, Janice are sitting on the couch, and Phoebe is
# sitting next to them in the chair.]
# [Scene: Monica and Rachel's, Carol and Susan are dropping off Ben]
# [Scene: Central Perk, Phoebe's beeper is going off]
# [Scene: Chandler and Joey's, Chandler and Janice are having dinner]
# [Scene: Monica and Rachel's, Monica and Rachel are comforting Chandler]
# [Scene: Monica and Rachel's, Ross is still trying to get Ben to play with something
# other than the Barbi doll.]
# [Scene: A grocery store that Janice shops in. Chandler is on purpose, accidentally
# bumping into her.]
# [Scene: Central Perk, Joey and Phoebe are there]
# [Scene: Chandler and Joey's, Chandler is laying on the counter and Rachel and Monica
# are comforting him again.]
# [Scene: Monica and Rachel's, Carol and Susan are picking up Ben, while Monica is
# pouring chocolate syrup, lots of it, into her ice cream.]
# [Scene: It's an old home movie of the Geller's backyard, young Ross is dressed up as
# Bea, and pouring himself/herself some tea.]
# [Scene: Chandler and Joey’s, there is lumber all over the apartment]
# [Scene: Outside Central Perk, Phoebe is pacing back and forth waiting for someone.]
# [Scene: inside Central Perk]
# [Scene: Chandler and Joey’s, Joey is drilling a hole in the wall and the drill
# comes out the other side really close to Chandler’s head. Chandler then rushes out to
# talk to Joey.]
# [Scene: Monica and Rachel’s, Joey is entering]
# [Scene: Phoebe’s, Frank and her, are sitting on the counh, watching TV]
# [Scene: Central Perk, Ross is working on his list]
# [Scene: Phoebe’s, Frank is melting a plastic spoon.]
# [Scene: Monica and Rachel’s, Phoebe is eating breakfast with Monica while Frank is
# playing with num-chucks on the balcony]
# [Scene: Phoebe’s, Phoebe and Frank are watching TV.]
# [Scene: Monica and Rachel’s bathroom, Joey and Monica are admiring the new floor.]
# [Scene: Healing Hands Inc. (Phoebe’s work), Frank is being ushered in, by the arm,
# to the room Phoebe is in by another girl.]
# [Scene: Chandler and Joey’s, everyone is there, helping to lift the entertainment
# center into place]
# [Scene: Central Perk, Rachel is serving some guy coffee.]
# [Scene: Chandler and Joey’s, they are admiring the entertainment center]
# Episode dialogue
# [Scene: Central Perk, the whole gang is there including Janice.]
# [Scene: Monica and Phoebe’s, three years earlier, Phoebe, Monica, and Ross are
# there]
# [Scene: Chandler’s, Chandler is interviewing a potential roommate.]
# [Scene: Chandler’s, Chandler is interviewing Joey.]
# [Scene: the hallway, Monica is coming up the stairs.]
# [Scene: A bar, Chandler is entering.]
# [Scene: Monica and Phoebe’s, Ross is on the phone, as Phoebe is walking by
# carrying a lamp.]
# [Scene: the hallway, Joey is moving in, Monica is leaving.]
# [Scene: continued from earlier.]
# [Scene: Monica and Phoebe’s, Monica is vacuuming.]
# [Scene: Chandler and Joey's, (now) Joey is watching Baywatch , as Chandler enters
# from his bedroom.]
# [Scene: Monica’s, Monica is coming out of the bathroom wearing nothing but a
# towel, as Chandler is entering.]
# [Scene: the bar, Ross is entering, Phoebe is at the bar, they are the only two in the
# place.]
# [Scene: Monica’s, Chandler and Monica are still hugging each other.]
# [Scene: the bar, Phoebe is still hugging Ross.]
# [Scene: the bar, Chandler is playing pool, as Rachel enters.]
# [Scene: Central Perk, the whole gang is there, Ross is telling a story about what
# happened at work and the rest of the gang are thinking to themselves, denoted by italics.]
# [Scene: Monica and Rachel's, the whole gang is there including Janice, they’re
# watching Happy Days .]
# [Scene: Central Perk, Rachel is on the phone, everyone else is there except Joey.]
# [Scene: Mattress King, Monica and Phoebe are shopping for a new mattress.]
# [Scene: Classroom. Joey is writing his name on the board, but turns around before
# he’s done which causes him to write his name with a downward curve, and he then
# underlines it, and draws the line right through his name.]
# [Scene: Monica and Rachel's, Joey is entering, Phoebe is already there waiting for the
# delievery guy.]
# [Scene: Restaurant, Rachel and Ross and Dr. Green are having dinner.]
# [Scene: After dinner.]
# [Scene: Classroom, Joey is lecturing on facial expressions.]
# [Scene: Hallway, Ross and Rachel are returning from dinner.]
# [Scene: Monica’s bedroom, Phoebe is trying to hide the bed from Monica.]
# [Scene: Classroom, Joey is coaching his student.]
# [Scene: Central Perk, Chandler, Monica, and Phoebe are there, yelling at Joey.]
# [Scene: Monica and Rachel's, Rachel is greeting her Father for their brunch.]
# [Scene: Classroom, Joey is talking to his students.]
# [Scene: Mattress King, Monica is trying to return her bed.]
# [Scene: Monica’s bedroom, Chandler is playing with the bed.]
# [Scene: Monica and Rachel's, Phoebe, Chandler, and Ross are there, Rachel
# is serving brownies.]
# [Scene: Central Perk, Ross, Rachel, and Phoebe are there.]
# [Scene: Monica and Rachel's, All are there except for Chandler.]
# [Scene: Monica and Rachel's, Monica and Rachel are babysitting Ben.]
# [Scene: The street, Chandler and Joey are walking past a jewelery store.]
# [Scene: Monica and Rachel's, Monica and Rachel are dressing up Ben in the entire rain
# suit from Rainy Day Bear.]
# [Scene: Chandler and Joey's, Chandler is waiting for Janice to arrive, and is angrily
# fllipping through a magazine.]
# [Scene: Monica and Rachel's, Monica, Rachel, Phoebe, and Joey are there.]
# [Scene: Chandler and Joey's, Chandler is throwing darts, as Joey enters.]
# [Scene: Monica and Rachel's, Ross has just finished putting Ben to sleep, and is
# entering from Rachel’s room.]
# [Scene: Central Perk, Chandler and Janice are there.]
# [Scene: Monica and Rachel's, Joey, Rachel, Monica, Phoebe, and Ross are holding the
# giant poking device.]
# [Scene: Chandler and Joey's, Chandler is listening to a Lionel Richie album]
# [Scene: Monica and Rachel's, the whole gang is there, the guys are
# watching football, the girls are cooking Thanksgiving dinner.]
# [Scene: Monica and Rachel's, continued from earlier.]
# [Scene: The Park, the gang is warming up for their football game.]
# [Scene: The park, the gang is returning to play the second half of the game.]
# [Scene: Monica and Rachel's, Rachel, Phoebe, Chandler, and Joey are eating Thanksgiving
# dinner.]
# [Scene: The park, it’s dark outside and Monica and Ross are still fighting over
# the ball.]
# [Scene: Central Perk, Chandler and Rachel are sitting on the couch.]
# [Scene: The hallway of Ross’s building, there is a Brown Bird girl selling
# cookies, as Ross and Chandler come up the stairs.]
# [Scene: Central Perk, the gang’s all there discussing the incident.]
# [Scene: Sarah’s bedroom, her room is decorated with a space motif.]
# [Scene: A hallway, Ross is selling Brown Bird cookies for Sarah, he stops and knocks on
# a door.]
# [Scene: Joey’s work, selling Christmas trees.]
# [Scene: Central Perk, all except Phoebe are there, Ross is telling the gang, minus
# Rachel who’s still being retrained, about the different cookie options.]
# [Scene: Monica and Rachel's, Chandler is entering numbers on a calculator as Ross reads
# off how much he’s sold.]
# [Scene: Joey work, Joey is showing a guy a tree.]
# [Scene: A Brown Bird meeting, Ross is there with the other Brown Birds to see who won
# the contest.]
# [Scene: Central Perk, Chandler, Phoebe, and Ross are there.]
# [Scene: The hallway between the two apartments, Chandler, Phoebe, Ross, and Rachel are
# coming up the stairs.]
# [Scene: Central Perk, Rachel is serving her last cup of coffee.]
# [Scene: Rachel’s new job, Rachel’s boss is telling her what to do.]
# [Scene: The hallway between the apartments, Ross is bringing Sarah to Joey and
# Chandler’s.]
# [Scene: Monica and Rachel's, Monica, Phoebe, Ross, Joey, and Rachel are
# there, Joey is demonstrating a card trick.]
# [Scene: Monica and Rachel's, continued from earlier.]
# [Scene: Fortunata Fashions, Rachel’s new job.]
# [Scene: The Moondance Diner, Rachel is talking to Monica about her job.]
# [Scene: Chandler and Joey's, it’s Joey’s party.]
# [Scene: Monica and Rachel's, Monica, Phoebe, Ross, and Rachel are eating breakfast.]
# [Scene: Monica and Rachel's, continued from earlier.]
# [Scene: Monica and Rachel's, Monica is writing letters as Rachel enters.]
# [Scene: Chandler and Joey's, Ross is reading a letter that Chandler wrote.]
# [Scene: Joey’s sister’s house, Chandler hits himself on the head three times
# and knocks on the door three times. Joey answers it.]
# [Scene: Central Perk, Monica, Ross, and Rachel are there.]
# [Scene: Joey’s sister’s house, they’re finishing up dinner.]
# [Scene: A lobby, Ross is waiting for Rachel, after her interview.]
# [Scene: Monica and Rachel's, The entire gang is there.]
# [Scene: Monica and Rachel's, Rachel is getting ready for her first day.]
# [Scene: Chandler and Joey's, Ross and Chandler are entering, Joey is on the phone.]
# [Scene: Rachel's office, Mark is training Rachel.]
# [Scene: The Moondance diner, Monica is cleaning up with one of the waiters, with her
# back turned to him she removes her fake breasts and hides them under her wig.]
# [Scene: Joey's audition.]
# [Scene: Chandler and Joey's, Chandler is reading Joey's resume.]
# [Scene: Rachel's office, her desk is covered with stuff Ross has sent her.]
# [Scene: Monica and Rachel's, Ross and Rachel are entering the living room from her
# bedroom.]
# [Scene: Central Perk, Chandler, Ross, Joey are there.]
# [Scene: Rachel's office.]
# [Scene: Joey's dance audition, Joey is warming up.]
# [Scene: Monica and Rachel's, Monica is tying a ribbon to a vase.]
# [Scene: The Moondance Diner.]
# [Scene: Joey's audition, the director has returned and wants to see the combination.]
# [Scene: Central Perk, Chandler and Rachel are there.]
# [Scene: The Moondance Diner.]
# [Scene: A Video Store, Monica is running in to return a video.]
# [Scene: continued from earlier.]
# [Scene: Monica and Rachel's, Chandler, Ross. Joey, and Rachel are eating breakfast.
# Chandler is holding a bottle of Hersey’s Syrup .]
# [Scene: Chandler and Joey's, Joey is watching TV.]
# [Scene: Central Perk, Chandler and Ross are there, Phoebe is entering with her date
# Robert.]
# [Scene: Monica and Rachel's, Monica is teaching Richard how to make lasagne.]
# [Scene: Central Perk, Chandler is watching Joey read Little Women , Ross is also
# there.]
# [Scene: Monica and Rachel's, Monica is talking to Richard on the phone.]
# [Scene: Monica’s bedroom, she’s in bed with Richard.]
# [Scene: Central Perk, Robert is picking up Phoebe for a date.]
# [Scene: Monica and Rachel's, Rachel is reading The Shining , as Monica enters.]
# [Scene: Central Perk, Phoebe, Chandler, and Ross are there.]
# [Scene: Richard’s bedroom, Monica has covered it in rose pedals and candles. We
# hear Richard come in to the apartment, and Monica frantically throws the rest of the
# pedals on the bed, and jumps onto the bed and puts a rose in her mouth, and bites a
# thorn.]
# [Scene: Monica and Rachel's, Joey is entering, and he’s very dejected.]
# [Scene: Central Perk, the gang, except Rachel, is watching a new singer.]
# [Scene: Central Perk, later.]
# [Scene: Outside the bathroom, Chandler is pacing back and fourth, waiting is use it.]
# [Scene: Central Perk, the gang’s putting their coats on to leave.]
# [Scene: Rachel’s office, Mark is packing his stuff into a box.]
# [Scene: Monica and Rachel's, Phoebe and Monica are playing with a Ouija board,
# Phoebe’s beeper goes off and Monica screams.]
# [Scene: A street, Chandler is kissing Ginger.]
# [Scene: Ross’s bedroom, Rachel getting into bed while Ross is reading and laughs.]
# [Scene: Monica and Rachel's, Phoebe is looking at her beeper still in the pot. She
# takes it out, shakes it, and puts it back in.]
# [Scene: Central Perk, Leslie is singing.]
# [Scene: The lecture, Rachel is listening closely, Ross is bored out of his mind.]
# [Scene: Central Perk, Phoebe is teaching Leslie how to sing Smelly Cat.]
# [Scene: The lecture, Ross is passed out against Rachel’s shoulder.]
# [Scene: Chandler and Joey's, Chandler is reading the newspaper.]
# [Scene: Monica and Rachel's, Ross and Rachel are getting back from the lecture.]
# [Scene: Chandler and Joey's, Chandler and Ginger are eating dinner.]
# [Scene: Central Perk, Phoebe is getting ready to sing as Leslie enters.]
# [Scene: Monica and Rachel's, Phoebe, Monica, and Joey are watching TV.]
# [Scene: Monica and Rachel's, the whole gang except Chandler is there.]
# [Scene: Monica and Rachel's, Joey is taking a jar of olives out of the
# fridge.]
# [Scene: The Xerox place, Chandler and Joey are waiting in line.]
# [Scene: A Street, Phoebe is walking along with the diplomat (Sergei) and his translator
# (Mischa).]
# [Scene: Monica and Rachel's, Phoebe is showing Monica where Sergei’s country is.]
# [Scene: Central Perk, Chandler and Joey are sitting on the big couch.]
# [Scene: Rachel’s office, Rachel and a co-worker (Sophie) are dealing with the
# crisis.]
# [Scene: Monica and Rachel's, Ross is eating the picnic as Rachel comes home from work.]
# [Scene: The Philly, Chandler and Joey are talking to Chloe.]
# [Scene: A Restaurant, Monica and Phoebe are on their dates with Sergei and Mischa.]
# [Scene: Monica and Rachel's, Rachel is lying in front of the bay window, and the phone
# rings.]
# [Scene: The Philly.]
# [Scene: Monica and Rachel's, Mark is there, opening Chinese food boxes.]
# [Scene: The Restaurant, after dinner.]
# [Scene: The Philly, With or Without You is playing. (Which is the same song Ross
# played for Rachel in TOW the List.)]
# [Scene: Monica and Rachel's, Rachel is next to the bay window again, Mark has left.]
# [Scene: The Philly, Ross is dancing with Chloe.]
# [Scene: Central Perk, Sergei is teaching Phoebe how to sing American Pie , by Don
# Maclean.]
# Episode dialogue
# [Scene: Monica and Rachel's, Ross is eating the picnic as Rachel comes home from work.]
# [Scene: Monica and Rachel's, Mark is there, opening Chinese food boxes.]
# [Scene: The Philly.]
# [Scene: Monica and Rachel's, Monica is making a fruit drink in the blender, Rachel has
# just finished her shower and is coming out of the bathroom.]
# [Scene: Ross’s Bedroom, Ross is waking up. He straightens himself out on the bed
# and puts the covers over his head.]
# [Scene: Ross’s Kitchen, Ross is taking some aspirin and checking his messages.]
# [Scene: Monica and Rachel's, Phoebe is entering carry a large box, Monica is mopping
# the ceiling.]
# [Scene: Chandler and Joey's, Ross has told Chandler and Joey his terrible act.]
# [Scene: Monica's Bedroom, Monica and Phoebe are waxing their legs.]
# [Scene: The Xerox Place, Ross is trying to break the trail.]
# [Scene: Phoebe’s Work, Ross is now trying to stop Jasmine from telling Phoebe.]
# [Scene: Central Perk, Gunther is wiping down the counter as Ross rushes in.]
# [Scene: Monica’s Bedroom, Monica and Phoebe are removing the rest of their wax
# strips.]
# [Scene: Monica’s bedroom.]
# [Scene: Central Perk, Chandler and Joey are sitting on the couch reading.]
# [Scene: Chandler and Joey's, the whole gang is there, except for Ross and Rachel. Joey
# is trying to eat Chinese with chopsticks and fails miserably. There’s a knock on the
# door, and Chandler answers it to reveal Rachel]
# [Scene: Ross’s, the gang, minus Rachel of course, is there. Chandler is forced to
# smoke by an open window.]
# [Scene: In Phoebe’s Grandmother’s cab, driving up to the cabin. Phoebe’s
# driving, Rachel’s sitting shotgun, Chandler, Monica, and Joey are in the back seat.]
# [Scene: The rest stop, Phoebe’s pulling in.]
# [Scene: The rest stop, the gang is still stuck, Chandler is kneeling at the rear
# bumper.]
# [Scene: Carol and Susan’s, Carol is setting a romantic dinner for Susan as there
# is a knock on the door.]
# [Scene: The rest stop, Phoebe is on the phone to the motor club.]
# [Scene: Carol and Susan’s, Ross is eating the dinner Carol made for Susan.]
# [Scene: The rest stop, Joey is making a sign.]
# [Scene: Carol and Susan’s, Carol is running to answer the door.]
# [Scene: Central Perk, all but Chandler are there, Joey laughs for no apparent reason.]
# [Scene: Central Perk, continued from earlier, Ross is handing Rachel a cup of coffee.]
# [Scene: Chandler’s bedroom, Chandler is listening to the hypnosis tape.]
# [Scene: The Moondance Diner, Monica is working, Rachel is having lunch.]
# [Scene: Chandler and Joey's, Ross and Joey are being lectured by Phoebe.]
# [Scene: Monica and Rachel's, Rachel and Monica are entering.]
# [Scene: Chandler and Joey's, Ross and Joey are talking to Frank.]
# [Scene: Chandler and Joey's, it’s after Ross and Joey’s talk with Frank, and
# Phoebe’s is finding out what happened.]
# [Scene: Phoebe’s, Phoebe is opening the door.]
# [Scene: Pete’s office, he is participating in a conference call with three other
# employees, each of whom are on a different TV screen that he controls with a remote.]
# [Scene: Phoebe’s, she is coming home. She turns on the lights, and sits down on
# the couch.]
# [Scene: Monica and Rachel's, Rachel is getting Monica ready for her date. The guys are
# also there. The door buzzes.]
# [Scene: A restaurant in Rome, Monica is paying for the pizza.]
# [Scene: Chandler and Joey's, it’s the middle of the night. Joey is walking into
# the living room, and runs into the entertainment centre.]
# [Scene: Phoebe’s, Frank is watching TV, and he’s very depressed as Phoebe
# enters.]
# [Scene: Chandler’s bedroom, he’s listening to the hypnosis tape again.]
# [Scene: Central Perk, Gunther is pouring Rachel coffee.]
# [Scene: The hallway between the two apartments, Pete and Monica are returning from
# their date.]
# [Scene: A Theatre, Joey is arriving to rehearse the play he’s in.]
# [Scene: Central Perk, Rachel is telling Phoebe about Mark, as Gunther eavesdrops behind
# them.]
# [Scene: Chandler and Joey's, Joey is telling Chandler about Kate.]
# [Scene: Monica and Rachel's, Rachel is there as Ross enters, walking very confidently.]
# [Scene: Central Perk, the gang minus Rachel and Ross are talking to Pete.]
# [Scene: The Theatre, Joey and Kate are rehearsing for the play.]
# [Scene: The Hallway, Chandler and Ross are returning from working out.]
# [Scene: Chandler and Joey's, Chandler is watching a basketball game, Ross is staring
# out the peephole.]
# [Scene: Monica and Rachel's, Rachel is pouring Mark some coffee.]
# [Scene: A Hospital Reception, Monica and Pete are there.]
# [Scene: Chandler and Joey's, Chandler is sitting in one of the black chairs, and turns
# to face the other one.]
# [Scene: The Theatre, Kate and Joey are rehearsing the same scene as before.]
# [Scene: Monica and Rachel's, Monica is in the kitchen chopping vegetables. Chandler and
# Phoebe are sitting in the living room.]
# [Scene: Chandler and Joey's, Phoebe and Chandler are sitting in the black chairs.]
# [Scene: Monica and Rachel's, Chandler, Monica, Phoebe, and Joey are there.]
# [Scene: Rachel’s office, Chandler and her are coming back from lunch.]
# [Scene: Monica and Rachel's, Monica is showing off her new dollhouse. It’s a huge
# dollhouse, that takes up the entire living room table.]
# [Scene: The Theatre, Joey and Kate are getting ready to rehearse the play.]
# [Scene: Monica and Rachel's, Phoebe is entering with her own dollhouse, that she made
# herself.]
# [Scene: Rachel’s office, Joanna’s telling Rachel, her side of the story.]
# [Scene: The Theatre, Joey and Kate are rehearsing.]
# [Scene: Monica and Rachel's, Ross and Monica are eating breakfast as Joey enters, very
# happily.]
# [Scene: Rachel’s office.]
# [Scene: Central Perk, Chandler is reading a magazine as Rachel approaches.]
# [Scene: Monica and Rachel's, Ross is entering.]
# [Scene: The Theatre, Kate is arriving for rehearsal.]
# [Scene: Monica and Rachel's, Monica and Ross are inspecting the damage to the
# dollhouse.]
# [Scene: Rachel’s office, Chandler and Joanna are returning from their lunch date.
# He is telling her about her mascara problem. Rachel is already there.]
# [Scene: Chandler and Joey's, Joey is talking on the phone.]
# [Scene: Outside Central Perk, Rachel and Phoebe are helping Monica learn
# how to roller skate by rolling her between themselves.]
# [Scene: Chandler and Joey's, Joey is watching Quincy M.E. as Chandler is
# walking into the living room from his bedroom.]
# [Scene: The Moondance Diner, Pete is entering, Monica is on roller skates.]
# [Scene: Monica and Rachel's, Monica is telling Rachel about Pete’s offer.]
# [Scene: Chandler and Joey's, Chandler is talking to Phoebe about her suggestion.]
# [Scene: The Moondance Diner, Pete is talking to Monica about the restaurant.]
# [Scene: Chandler and Joey's, Chandler is baby-chick sitting.]
# [Scene: Monica and Rachel's, Rachel is trying to take some aspirin.]
# [Scene: Rachel’s bedroom, Rachel is trying to put on eye liner with her left
# hand, as Ross is setting out her shoes.]
# [Scene: Central Perk, Monica is entering, Phoebe is already there.]
# [Scene: Rachel’s Bedroom, Ross is finishing up her make-up.]
# [Scene: Central Perk, Monica is trying to find out what Phoebe won’t tell her.]
# [Scene: Chandler and Joey's, Chandler is watching Baywatch with the baby chick.
# He’s on one leather chair, the chick is on the other. It’s watching Yasmine
# Bleeth run and is chirping.]
# [Scene: Pete’s Restaurant’s Kitchen, Pete is showing Monica around the
# kitchen.]
# [Scene: The Hallway Between The Apartments, Ross and Rachel are coming back from the
# hospital. Ross is helping her up the stairs.]
# [Scene: Chandler and Joey’s Bathroom: Chandler is watching the duck swim in
# the bathtub.]
# [Scene: Monica and Rachel's, Phoebe is on the phone, Chandler and Monica are sitting in
# the living room, and Ross is in the kitchen as Rachel enters from her bedroom.]
# [Scene: Monica and Rachel's, Monica is getting ready to go to Joey’s premiere and
# Phoebe is still on hold.]
# [Scene: Joey’s Premiere, Rachel is already there with her date, Tommy who's played
# by Ben Stiller who will be in There's Something About Mary and Meet The
# Parents , as Ross and his date, Cailin, arrive.]
# [Scene: The Theatre, at the post premiere party. The gang is already there, except
# Phoebe. Joey runs in.]
# [Scene: Monica and Rachel's, Monica and Rachel are returning. Phoebe is still on
# hold.]
# [Scene: The Theatre, after the party. Joey is trying to comfort Kate.]
# [Scene: Kate’s Apartment, Joey and Kate are returning from a night out on the
# town.]
# [Scene: Monica and Rachel's, the next morning, Phoebe is STILL on hold.]
# [Scene: Central Perk, Chandler and Monica are sitting on the couch, Rachel is on the
# chair.]
# [Scene: Backstage at Joey’s play, Joey is arriving, late.]
# [Scene: Monica and Rachel's, Chandler and Ross are in the kitchen, Rachel and Monica
# are sitting in the living room, and Phoebe is, you guessed it, still on hold.]
# [Scene: Backstage at Joey’s play, Joey is changing for the next scene as Kate
# arrives, carrying her bags.]
# [Scene: Monica and Rachel's, the gang, except Joey, is there. Phoebe is, well you
# y'know.]
# [Scene: Chandler and Joey's, Chandler and Joey are playing with the duck and the
# chick.]
# [Scene: Central Perk, Chandler, Joey, and Rachel are there, as Phoebe enters with her
# date.]
# [Scene: A Street, Phoebe is walking with her second date, Jason.]
# [Scene: A Doctor's Office, Ross is having his thing looked at by Dr. Rhodes.]
# [Scene: Central Perk, Chandler, Monica, and Joey are there.]
# [Scene: Dr. Rhodes's Office, a rather large group of doctors has now gathered to take a
# look at Ross's thing. Ross is none too pleased with the developments, he has a disgusted
# look on his face.]
# [Scene: Pete's apartment, Monica is there to water the plants, and is showing the gang
# around.]
# [Scene: Monica and Rachel's, the gang is returning from Pete’s.]
# [Scene: A Fire House, Phoebe has gone to break up with Vince.]
# [Scene: Central Perk, Phoebe, Ross, and Monica are there.]
# [Scene: Jason’s apartment, Phoebe has gone to break up with Jason.]
# [Scene: Phoebe’s Herbal Guy’s office, Ross is there about his thing. Ross is
# looking around the exam room, and he goes over to a large bank of drawers, pulls one out
# and almost spills it as the herbalist, Guru Saj, enters.]
# [Scene: Pete’s apartment, Pete and Monica are coming back from a date.]
# [Scene: Central Perk, Phoebe’s singing, Vince is also there.]
# [Scene: Guru Saj’s office: Joey and Chandler have taken the duck to see the guru.]
# [Scene: Central Perk, the whole gang minus Monica is there.]
# [Scene: Central Perk, continued from earlier.]
# [Scene: Chandler’s office, he is just finishing a meeting with his boss.]
# [Scene: Monica and Rachel's, Ross is making reservations.]
# [Scene: A Gym, Pete is training for the Ultimate Fighting Championship, with his
# trainer, Hoshi.]
# [Scene: Central Perk, Phoebe is there with Bonnie, as Rachel enters.]
# [Scene: Chandler’s office, Chandler is bent over getting some water as his boss
# approaches.]
# [Scene: The Ultimate Fighting Championship, Ross and Monica are there watching Pete.]
# [Scene: The Arena, after the fight. Monica is walking up to a defeated Pete.]
# [Scene: Monica and Rachel's balcony, Ross and Phoebe are grilling some burgers and hot
# dogs.]
# [Scene: Chandler’s office, Chandler is confronting his boss about the butt
# smacking thing. His boss is writing on a white board.]
# [Scene: The street outside Central Perk, Rachel and Phoebe are talking and walking.]
# [Scene: A locker room, Pete is in a full upper-body cast. Monica enters, sees him, and
# gasps. Pete tries to turn around, and winces in pain.]
# [Scene: Chandler’s office, he is just finishing up a meeting with his boss and the
# rest of his team.]
# [Scene: Monica and Rachel's, the gang is watching Pete fight on TV. Monica is hiding in
# the kitchen, not watching.]
# [Scene: Central Perk, everyone except Phoebe is there. Bonnie is telling them of her
# sex-capades.]
# [Scene: Outside Central Perk, Chandler and Monica are waiting for Phoebe to arrive with
# the cab.]
# [Scene: At the Beach, it’s raining cats and dogs as the gang arrives. Chandler and
# Monica are taking shelter under Rachel’s hat.]
# [Scene: Phoebe Sr. house, she is a real estate agent and is trying to sell a house over
# the phone. By the way, it’s still raining outside.]
# [Scene: The beach house, it’s still raining. Chandler is building a sand castle,
# Rachel is doing Monica’s nails, and they’re all drinking margaritas, obviously
# bored.]
# [Scene: The beach house, the next morning. Chandler and Monica are in the kitchen
# eating breakfast.]
# [Scene: The porch, Bonnie is coming back from swimming, Rachel is reading.]
# [Scene: The beach house, at night. Phoebe is hangs up the phone, and gently pushes one
# of the stools over.]
# [Scene: Outside the beach house, Ross is coming out to talk to Rachel.]
# [Scene: Phoebe Sr.’s house, Phoebe is breaking in through a window.]
# [Scene: Outside the beach house, Ross is telling Joey and Chandler what happened with
# Rachel.]
# [Scene: The hallway between the bedrooms. Ross is coming upstairs and stops between two
# doors. He looks at the one on the right, then he looks at the one on his left, thinks
# about it, and goes in the one on his right.]
# [Scene: The beach house, Chandler is simulating he’s coming to pick up Monica for
# a date. Chandler knocks on the door, and Monica answers it.]
