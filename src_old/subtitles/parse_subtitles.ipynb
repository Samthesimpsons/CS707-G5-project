# %%
import json
import pandas as pd
import re

from pathlib import Path
from typing import List, Dict

# %% [markdown]
# ### Extract HTML Scripts

# %%
import json
import re

from pathlib import Path
from bs4 import BeautifulSoup  # type: ignore[import-not-found]
from typing import Any, Dict, List, cast

# %%
def parse_html_script_new(html_path: Path) -> Dict[str, Any]:
    with open(html_path, "r", encoding="utf-8") as f:
        content = f.read()

    soup = BeautifulSoup(content, "html.parser")

    title_tag = soup.find("title")
    title = title_tag.get_text() if title_tag else ""

    episode_num = html_path.stem
    scenes = []
    current_scene = {"scene_description": "Episode dialogue", "dialogue": []}

    # Skip terms in header/footer metadata
    skip_keywords = [
        "written", "transcribed", "originally", "minor",
        "adjustment", "story", "teleplay", "directed"
    ]
    max_speaker_len = 30

    def extract_multiple_speakers(text: str) -> List[Dict[str, str]]:
        """Extract all SPEAKER: dialogue pairs from a single line."""
        results = []
        pattern = re.compile(r"([A-Za-z][A-Za-z\s.'()/-]{0,30}):")

        matches = list(pattern.finditer(text))
        for i, m in enumerate(matches):
            speaker = m.group(1).strip()
            start = m.end()
            end = matches[i + 1].start() if i + 1 < len(matches) else len(text)
            dialogue = text[start:end].strip()

            # Clean + validate
            if any(k in speaker.lower() for k in skip_keywords):
                continue
            if len(speaker) > max_speaker_len:
                continue
            dialogue = re.sub(r"\s+", " ", dialogue).strip()
            if dialogue:
                results.append({"speaker": speaker.upper(), "text": dialogue})
        return results

    for p in soup.find_all("p"):
        raw = p.get_text(" ", strip=True)
        if not raw:
            continue

        # Scene detection like [Scene: ...]
        if raw.startswith("[Scene:") or raw.startswith("[Opening") or raw.startswith("[Closing"):
            if current_scene["dialogue"]:
                scenes.append(current_scene)
            current_scene = {"scene_description": raw, "dialogue": []}
            continue

        # Extract all speaker/dialogue segments in this paragraph
        pairs = extract_multiple_speakers(raw)
        if pairs:
            current_scene["dialogue"].extend(pairs)

    if current_scene["dialogue"]:
        scenes.append(current_scene)

    return {"episode": episode_num, "title": title, "scenes": scenes}

# %%
def convert_all_html_scripts(input_dir: Path, output_dir: Path) -> None:
    """Convert all HTML scripts to JSON format.

    Args:
        input_dir: Directory containing HTML script files.
        output_dir: Directory to save JSON files.
    """
    print(f"\n{'='*80}")
    print("Converting HTML Scripts to JSON (Edersoncorbari)")
    print(f"{'='*80}\n")

    output_dir.mkdir(parents=True, exist_ok=True)

    html_files = sorted(input_dir.glob("*.html"))

    episode_files = [f for f in html_files if re.match(r"^\d{4}", f.stem)]
    
    print(f"Found {len(episode_files)} episode scripts")

    for i, html_file in enumerate(episode_files, 1):
        try:
            if i % 10 == 0 or i == len(episode_files):
                print(f"Progress: {i}/{len(episode_files)}", end="\r")

            data = parse_html_script_new(html_file)

            output_file = output_dir / f"{html_file.stem}.json"
            with open(output_file, "w", encoding="utf-8") as f:
                json.dump(data, f, indent=2, ensure_ascii=False)

        except Exception as e:
            print(f"\nError processing {html_file.name}: {e}")

    print(f"\n\nHTML scripts converted: {len(episode_files)} files")
    print(f"Output directory: {output_dir}")

# %%
# data_dir = Path("./data")
html_input_dir = Path("./edersoncorbari_subtitles_html/bad")
html_output_dir = Path("./edersoncorbari_new_annotated")

if html_input_dir.exists():
    convert_all_html_scripts(html_input_dir, html_output_dir)
# Out:
# ================================================================================
# Converting HTML Scripts to JSON (Edersoncorbari)
# ================================================================================
#
# Found 1 episode scripts
# Progress: 1/1
#
# HTML scripts converted: 1 files
# Output directory: edersoncorbari_new_annotated

# %% [markdown]
# ### Parse Subtitles from Edersoncobari

# %%
def add_new_annotations(data: dict):
    episode = data.get("episode")
    scenes = data.get("scenes", [])
    for scene in scenes:
        ### Extract all unique subjects
        speakers_seen = []
        for turn in scene.get("dialogue", []):
            sp = turn.get("speaker")
            if isinstance(sp, str):
                sp_clean = sp.strip()
                if sp_clean:
                    if sp_clean not in speakers_seen:
                        if "ALL" not in sp_clean:
                            speakers_seen.append(sp_clean)
        
        ### Extract the location from scene description
        scene_description = scene.get("scene_description")
        print(scene_description)
        if not isinstance(scene_description, str):
            return ""
        else:
            m = re.search(r"\[Scene\s*[:\-]?\s*([^\],]+)", scene_description, flags=re.I)
            try:
                location = m.group(1).strip()
            except AttributeError:
                location = ""
        scene["location"] = location
        scene["subjects"] = list(set(speakers_seen))
        scene["srt_start"] = scene["clip_start"]
        scene["srt_end"] = scene["clip_end"]
        scene["clip_start"] = ""
        scene["clip_end"] = ""

    return data, episode

# %%
subs_dir = Path("./edersoncorbari_new_annotated")
output_dir = Path("./edersoncorbari_annotated")

json_subs = []
for file in sorted(subs_dir.rglob("*.json")):
    with open(file) as f:
        subs = json.load(f)
        json_subs.append(subs)
        f.close()                     

output_dir.mkdir(exist_ok=True)
for subs_data in json_subs:
    annotated_subs_data, episode = add_new_annotations(subs_data)
    save_dir = output_dir / f"{episode}.json"
    with open(save_dir, "w") as f:
        json.dump(annotated_subs_data, f, indent=4)
# Out:
# Episode dialogue
# [Scene: Museum of Prehistoric History, Ross and a co-worker
# (Marsha) are setting up an exhibit which includes some mannequins of cave people.]
# [Scene: Monica and Rachel's, Chandler, Joey, Phoebe, and Monica are watching Three's
# Company .]
# [Scene: Central Park, everyone's there.]
# [Scene: Carol's OB/GYN, Carol is waiting.]
# [Scene: Carol's OB/GYN, they're talking about how this is going to work.]
# [Scene: Barry's office, Rachel is doing her makeup in the mirror on Barry's lamp as
# Barry enters.]
# [Scene: Carol's OB/GYN, they're still arguing about what to name the baby.]
# [Scene: Monica and Rachel's apartment, everyone is watching the tape of the sonogram.
#   Rachel is on the phone.]
# Episode dialogue
# [Scene: Chandler and Joey's, Chandler is helping Joey rehearse for a part.]
# [Scene: Iridium, Monica and Paula are at work.]
# [Scene: Monica and Rachel's, Chandler is smoking out on the balcony, Phoebe is absent.]
# [Scene: Central Perk, Monica is alone as Ross, Rachel, Chandler, and Joey enter
# dejectedly in softball gear.]
# [Scene: A street, Phoebe walks up to a homeless person (Lizzie) she knows.]
# [Scene: A Street, Phoebe and Lizzie are at a hot dog vendor.]
# [Scene: Central Perk, Phoebe is telling everyone about her discovery.]
# [Scene: Iridium, Monica and Paula are working.]
# [Scene: Cental Perk, Joey and Ross are persecuting Chandler about his smoking.]
# [Scene: Monica and Rachel's, everyond except Monica and Joey is watching Lambchop.]
# [Scene: A Restaurant, Monica is breaking the news to Alan.]
# [Scene: Monica and Rachel's, everyone is mopping around and eating ice cream.]
# Episode dialogue
# [Scene: Central Perk, Ross and Monica are watching Phoebe
# sleep.]
# [Scene: A Street, Chandler and Joey are kicking a can to
# each other.]
# [Scene: Central Perk, Rachel, Lesile, Kiki, and Joanne are
# talking.]
# [Scene: Monica and Rachel's, Phoebe and Monica are in
# pajamas and Monica is making something in the blender as Rachel enters.]
# [Scene: Madison Square Garden , the guys are trying
# to find their seats.]
# [Scene: Monica and Rachel's, they're all hanging out in the
# living room.]
# [Scene: Madison Square Garden , the guys are
# watching the game.]
# [Scene: An Emergency Room, Chandler and Joey are leading
# Ross in.]
# [Scene: Monica and Rachel's, the slumber party continues.]
# [Scene: The Emergency Room, Joey is miming hockey pucks
# kitting foreheads.  Chandler realises it's getting tense and goes to the receptionist
# again.]
# [Scene: Monica and Rachel's, the girls are all out on the
# balcony.]
# [Scene: The Emergency Room, Ross is still going on about
# his first night with Carol.]
# [Scene: Monica and Rachel's, the girls are still out on the
# balcony.]
# [Scene: The Emergency Room, Ross is absent.]
# [Scene: Monica and Rachel's, Joey and the girls are playing
# twister.]
# [Scene: Central Perk, all six are there.]
# [Scene: Central Perk, all are there.]
# [Scene: Monica and Rachel's apartment, Joey is there, trying to convince Monica to pose
# as his girlfriend. His plan is to hook Monica up with Angela's boyfriend Bob and then take
# Angela back for himself.]
# [Scene: Ross' apartment, Chandler is over.]
# [Scene: A fancy restaurant, Joey and Monica are there, meeting Angela and Bob, who
# Monica thinks is Angela's brother.]
# [Scene: Central Perk, Chandler and Phoebe are there, both ready to break up with their
# significant others.]
# [Scene: The Launderama, Rachel is there, waiting for Ross. An old woman takes Rachel's
# clothes off the machine and begins loading it with her things.]
# [Scene: Fancy restaurant, Monica, Joey, Angela, and Bob are seated at the table.]
# [Scene: Fancy restaurant, Joey and Bob are talking.]
# [Scene: The ladies' bathroom at the restaurant, Monica and Angela are talking.]
# [Scene: Central Perk, Phoebe is coaching Chandler on how to break up with Janice.]
# [Scene: The laundromat.]
# [Scene: The fancy restaurant, Angela has her hand in Bob's shirt, and Monica is very
# uncomfortable.]
# [Scene: Central Perk, Chandler is still trying to ease things over with Janice, and
# there are about a dozen empty Espresso cups in front of him. He is extremely wired.]
# [Scene: The Launderama. Rachel is sorting her now-pink clothes.]
# [Scene: Central Perk, Ross, Rachel, and Phoebe are there. Ross has an icepack to his
# head.]
# Episode dialogue
# [Scene: The Theater, the play has ended and everyone is applauding.  As soon as
# the cast leaves, the gang all groan and sit down heavily.]
# [Scene: Central Perk, everyone else is there as Chandler enters.]
# [Scene: Monica and Rachel's, Rachel is there as enter except Joey enter.]
# [Scene: Monica and Rachel's, the next morning, Monica is getting the door.]
# [Scene: A Film Set, Joey is entering for his scene.]
# [Scene: Chandler and Joey's, Aurora and Chandler are in bed in Chandler's room.]
# [Scene: Monica and Rachel's, Ross is trying to comfort Chandler.  Joey is absent.]
# [Scene: Monica's Bedroom, she's lying in bed wide awake.]
# [Scene: Central Perk, Rachel is introducing Phoebe, who is playing her guitar for the
# crowd.]
# [Scene: The ATM vestibule of a bank, Chandler is inside. The lights go out, and he
# realizes he is trapped inside.]
# [Scene: Monica and Rachel's, Monica is on the phone with her mother. Phoebe, Rachel,
# and Ross are there.]
# [Scene: ATM vestibule, Jill Goodacre is on the cellular phone. Chandler's thoughts are
# in italics.]
# [Scene: Monica's apartment, Joey enters with a menorah, the candles lit.]
# [Scene: ATM vestibule.]
# [Scene: Monica and Rachel's, The phone rings; it's Chandler.]
# [Scene: Monica and Rachel's, time has passed. The five are sitting around the coffee
# table talking.]
# [Scene: ATM vestibule.]
# [Scene: Monica's apartment, Phoebe is singing.]
# [Scene: Monica and Rachel's Balcony, Ross and Rachel are talking.]
# [Scene: Monica and Rachel's, Phoebe is holding the cat, Monica is treating the
# scratches on Ross' back. Joey is holding the menorah over the wound.]
# [Scene: ATM vestibule.]
# [Scene: The hallway of Monica's building. Phoebe and Rachel are trying to find the
# cat's owner.]
# [Scene: Rachel has gone off on her own to look for the cat's owner.]
# [Scene: Monica and Rachel's, Ross, Monica, and Joey are playing Monopoly .]
# [Scene: ATM vestibule.]
# [Scene: Monica and Rachel's, Rachel and Paolo are at the window. Ross and Joey are
# watching disgustedly.]
# [Scene: ATM vestibule, Chandler and Jill are sitting below the counter with two pens
# dangling from their chains in front of them. Jill is showing Chandler how to swing the pen
# around his head.]
# [Scene: Monica and Rachel's, the gang is all sitting around the table.]
# [Scene: ATM vestibule, the power has come back on.]
# Episode dialogue
# [Scene: Monica and Rachel's, everyone is there.)
# [Scene: The Hospital, Mr. and Mrs. Geller are there, along with Aunt Lillian. Ross and
# Monica enter and everyone says hi and kisses.)
# [Scene: Central Perk, Chandler, Phoebe, Joey, and Rachel are there.]
# [Scene: Nana's house, Ross, Mrs. Geller and Aunt Lillian are going through clothes.]
# [Scene: Monica and Rachel's, Monica is talking to her father.]
# [Scene: Chandler's Office, Shelley is drinking coffee; Chandler enters.]
# [Scene: Nana's Bedroom, Ross is holding a dress out from inside the closet.]
# [Scene: Monica and Rachel's, Monica and Rachel are preparing to leave for the funeral.]
# [Scene: The cemetary, after the funeral.]
# [Scene: The Wake, at the Gellers' house. Ross is lying on his back, with Phoebe
# squatting over him, checking to see if he's injured.]
# [Scene: Central Perk, the gang are looking at old photos.]
# [Scene: Chandler's Office, Chandler is on a coffee break as Lowell enters.]
# [Scene: Central Perk, Rachel is confronting her boss, Terry.]
# [Scene: Central Perk, Rachel is approaching a customer.]
# [Scene: Carol and Susan's apartment, Susan is there. Ross enters.]
# [Scene: Monica and Rachel's, everyone is there but Rachel.]
# [Scene: The subway, Joey spots a gorgeous woman waiting. He goes up to her.]
# [Scene: Central Perk, Joey enters, amongst snickers from the gang.]
# [Scene: Monica and Rachel's, Joey enters, upset.]
# [Scene: Monica and Rachel's, Monica is cooking Thanksgiving dinner. Chandler is
# standing in the doorway, not wanting to participate in the festivities.]
# [Scene: Carol and Susan's, Ross is preparing to talk to her belly.]
# [Scene: Monica and Rachel's, the group is coming back from the roof.]
# [Scene: Carol and Susan's, Carol is reading, Ross is talking to her stomach.]
# [Scene: The Hallway, Joey has a tray full of keys, and is trying each one in the lock.]
# [Scene: Monica and Rachel's, Ross is entering.]
# [Scene: Central Perk, Phoebe is getting ready to sing. Joey is not there.]
# [Scene: Monica and Rachel's, everyone except Joey is decorating for Christmas.]
# [Scene: Max and David's lab, David is explaining something to Phoebe with the aid of a
# whiteboard.]
# [Scene: Central Perk, everyone is there.]
# [Scene: Max and David's lab, they are working. Phoebe knocks on the door]
# [Scene: Monica and Rachel's, the party has started.]
# [Scene: Monica and Rachel's, time lapse.]
# [Scene: A Street: Monica and Phoebe are walking to a newsstand.]
# [Scene: Hospital, the guy is in a coma and Mon and Pheebs are visiting.]
# [Scene: Monica and Rachel's, Monica and Phoebe are telling everyone about their coma
# guy.]
# [Scene: The Hospital, it's a montage of Monica and Phoebe's visit to the hospital with My
# Guy playing in the background.  It starts with Monica reading a newspaper to
# him.]
# [Scene: A Mexican Restaurant, Monica, Phoebe, Joey, Chandler and his mom are there.]
# [Scene: Chandler and Joey's, the next morning. Joey is getting the door in his dressing
# gown—it's Ross.]
# [Scene: Hospital. Phoebe is there stroking Coma Guy's hair, when Monica enters with a
# bunch of balloons.]
# [Scene: Chandler and Joey's, Ross is talking to Chandler. Joey is making a snack at the
# bar.]
# [Scene: Central Perk, everyone is there except for Chandler.  Rachel is writing
# something and Monica walks up.]
# [Scene: The Coma Guy's Room, Monica bursts in, closely followed by Phoebe. There is no
# sign of Coma Guy.  His bed is empty.]
# [Scene: Chandler and Joey's Chandler is talking with his mom.]
# [Scene: Monica and Rachel's, Rachel is handing out copies of her book to the gang.]
# [Scene: Central Perk, everyone is there. Ross working on
# crossword puzzle, starts humming theme from The Odd Couple . Chandler joins in,
# followed by Monica and Phoebe, then the whole gang. Ross starts humming theme from I
# Dream Of Jeannie .]
# [Scene: Monica and Rachel's, Monica is on the phone in the kitchen.]
# [Scene: The Hallway, Chandler and Joey leaving girls' apartment, carrying lasagna.]
# [Scene: Carol and Susan's, there's a knock on the door and Carol answers it to Ross.]
# [Scene: Chandler and Joey's,  Joey and Chandler use their knees as a table to
# support the lasagna.]
# [Scene: Phoebe's Massage Parlor, Phoebe's assistant is telling her about the changes to
# her schedule.]
# [Scene: Central Perk, everyone but Phoebe is there.]
# [Scene: Central Perk, continued from earlier.]
# [Scene: The Table Store, Joey and Chandler and looking for their new table.]
# [Scene: Monica and Rachel's, Rachel folding and packing clothes in suitcases as Phoebe
# enters.]
# [Scene: Chandler and Joey's, Ross, Chandler, Joey, and Monica admiring their new
# table.]
# [Scene: Monica and Rachel's, Rachel is recovering from the shock.]
# [Scene: Chandler and Joey's, Phoebe is telling everyone how it went across the hall as
# the foosball game continues.]
# [Scene: Monica and Rachel's Balcony, Rachel is throwing Paolo's clothes over the side.]
# [Scene: Chandler and Joey's, Monica is busy killing Chandle and Joey at foosball.]
# [Scene: Monica and Rachel's, Chandler walks in and starts raiding the
# fridge. Then Rachel comes out of the shower with a towel wrapped round her waist, drying
# herself with another towel. Chandler and Rachel startle each other and she drops the towel
# for a second and snatches the rug off the couch.]
# [Scene: Central Perk, Phoebe is there with her boyfriend Roger, talking to Rachel and
# Monica.]
# [Scene: Chandler and Joey's, Mr. Tribbiani is on the phone.]
# [Scene: Monica and Rachel's, Joey is lamenting to everyone about hid dad's affair.]
# [Scene: The Hallway, Chandler and Joey are just leaving Monica and Rachel's.]
# [Scene: Chandler and Joey's, Ronni is talking to Chandler. Joey's dad is not around.]
# [Scene: Chandler and Joey's, night. Chandler and Joey are sharing the sofabed in the
# living room. Joey is restless.]
# [Scene: Monica and Rachel's, morning. Someone knocks on the door and Monica gets it.]
# [Scene: Central Perk, everyone is there as Phoebe enters.]
# [Scene: Chandler and Joey's apartment, Joey is trying to turn the sofabed back into a
# sofa. Someone knocks on the door and it rears up at him.]
# [Scene: Central Perk. Phoebe is there with Roger.]
# [Scene: Monica and Rachel's, Joey is letting everyone in on the new developments.]
# [Scene: Monica and Rachel's. Phoebe is reading the paper and Joey enters.]
# [Scene: Central Perk, Ross is eyeing a beautiful woman at the counter, and Joey and
# Chandler are egging him on to go talk to her. No pun intended. I mean it.]
# [Scene: Central Perk, Monica, Rachel, Phoebe, Joey, Chandler are there. Ross is still
# talking to the beautiful woman.]
# [Scene: A Restaurant, Joey and Chandler are there, waiting for their dates to show up.]
# [Scene: The bathroom at the restaurant, Chandler and Joey are talking.]
# [Scene: Monica and Rachel's, the girls are all there, discussing their bad luck with
# men.]
# [Scene: The Restaurant, Joey, Lorraine, Chandler, and Janice are at the table. Joey and
# Lorraine are seated very close, Chandler and Janice have backed their chairs away from one
# another.]
# [Scene: Chandler's bedroom, Chandler wakes up, and finds someone else's hand on his
# chest. He rolls over and is shocked to see Janice there.]
# [Scene: The Hallway, Chandler is trying to get Janice out of his apartment.]
# [Scene: A Chinese Restaurant, Ross is there with his date.]
# [Scene: Monica and Rachel's, the girls are holding their boyfriend bonfire.]
# [Scene: Central Perk, Chandler and Joey are there. Chandler is preparing to dump Janice
# again.]
# [Scene: The Chinese Restaurant.]
# [Scene: Monica and Rachel's, firemen are there to handle the bonfire that got out of
# control.]
# [Scene: Central Perk.]
# [Scene: The Chinese Restaurant, Ross and Carol are talking. Kristin is not there.]
# [Scene: Monica and Rachel's, The girls are talking with the firemen.]
# [Scene: Central Perk, Rachel is serving Joey, Ross, and Monica their drinks.]
# [Scene: Chandler's job, Chandler is typing data into his computer, he keeps typing even
# while taking a drink of coffee with one hand. One of his co-workers walks by.]
# [Scene: Central Perk, everyone is there but Chandler. Phoebe runs in, excitedly.]
# [Scene: Monica and Rachel's, Chandler walks in, wearing a suit.]
# [Scene: Ross's apartment, Marcel is hanging from Celia's hair, and she is screaming,
# trying to get him off.]
# [Scene: Monica and Rachel's, everyone is there but Ross and Chandler. Monica is making
# food, and having everyone try it.]
# [Scene: Ross' apartment, Girl, You'll Be A Woman Soon (the original, not that
# cruddy Urge Overkill version) is playing. Ross and Celia are kissing passionately.]
# [Scene: Chandler and Joey's, Joey and Ross are there, discussing what happened last
# night.]
# [Scene: Chandler's new window office, he is showing Phoebe around.]
# [Scene: Monica and Rachel's, Monica is on the phone. Rachel walks in and overhears the
# conversation.]
# [Scene: Monica and Rachel's, later. Rachel is waitressing, Monica is cooking. Phoebe
# walks in with Steve ( Crystal Duck winner Jon Lovitz).]
# [Scene: Central Perk, all are there except Chandler.]
# [Scene: Chandler's office, he's on the phone, agitated.]
# [Scene: Phoebe's massage parlour, she has Steve on the table, and is giving him an
# extra-painful massage.]
# [Scene: The Lamaze class, several couples and one trio sit on the floor, introducing
# themselves to the teacher, who’s got as far as a woman sitting next to Ross, Carol,
# and Susan.]
# [Scene: An Emergency Room, Rachel and Monica enter.  Rachel is limping and leaning
# on Monica for support.]
# [Scene: Central Perk, Chandler, has split up his newspaper so Joey can look at the
# funnies, while Ross's inappropriate joke at Lamaze class has come back to haunt him.]
# [Scene: The Hospital, Monica and Rachel are waiting for the doctors to arrive.
# They enter and are played by Noah Wyle and George Clooney.]
# [Scene: Monica and Rachel's, everyone but Joey is waiting for Phoebe to arrive for her
# surprise birthday party.  Rachel and Monica is telling Chandler about Rachel's
# incident.]
# [Scene: A Restaurant, Ross is having lunch with his father who is examining his next
# forkful.]
# [Scene: Monica and Rachel's, Monica is just getting off of the intercom and turns off
# the TV which is still in the SAP mode.]
# [Scene: Monica and Rachel's, the next morning, Ross, Phoebe, Chandler and Monica sit
# round the coffee table, playing Scrabble. Rachel, still in her dressing gown, is pleading
# on the phone, her free hand shaking with agitation.]
# [Scene: Riff's, Phoebe is entering. Ursula returns with two plates of chicken, but she
# only has time to set one on the table, when...]
# [Scene: The Emergency Room. The officious admissions nurse is again on duty. Rachel and
# Monica enter, looking worried. As they approach the desk, Rachel adopts a winning smile,
# while Monica struggles to smile at all.]
# [Scene: Monica and Rachel's, Chandler is neglecting the game of Scrabble , for
# he's busily drawing on his own childhood in an attempt to help Ross. Marcel chitters
# about.]
# [Scene: The Emergency Room, Monica sits with Rachel, who is filling out an honest form
# at last. Ross and Chandler hurtle in. Little Marcel, wrapped in a fluffy towel, is cradled
# in Ross's arms. They dash up to the admissions desk. Ross is frantic.]
# [Scene: Central Perk, Joey is playing "She Loves Me, She Loves Me Not" with
# the petals of a flower, alternately looking hopeful and annoyed. Phoebe enters, but not as
# herself, for she has changed the style of her hair and make-up to match that of her twin
# sister. She hangs up her coat, revealing her new cardigan. Nervously, she smooths out the
# identifying garment, approaching Joey who sits next to the main sofa.]
# [Scene: The Hospital, Marcel lies on the operating table while recovering from the
# anaesthetic, tucked up under a sheet like an infant in a huge bed. Ross sits beside him,
# as a smiling Chandler, Monica and Rachel look on.]
# [Scene: Monica and Rachel's, everyone except Joey is there.  Rachel is looking out
# of the window and Ross is handing out some Chinese takeout.  There's a small SAP in
# the corner of the screen.]
# Episode dialogue
# [Scene: Central Perk, Ross and Chandler are sitting at a table. Rachel is working.
# Monica and Phoebe enter.]
# [Scene: Monica and Rachel's, the guys are teaching the girls how to play poker.]
# [Scene: Ross' apartment. Chandler and Joey are there. Ross enters with a pizza.]
# [Scene: Monica and Rachel's, Rachel, Monica, and Phoebe are there.]
# [Scene: Ross's apartment, everyone but Rachel is seated around his table. The Lion
# Sleep Tonight plays in the background.]
# [Scene: Ross's Apartment, continued from earlier.]
# [Scene: Monica and Rachel's, everyone is there ready for another poker game.]
# [Scene: Monica and Rachel's, all six are playing Pictionary at Monica's
# apartment. Monica is drawing a picture, and the three guys are guessing. She draws what
# looks like an airplane.]
# Episode dialogue
# [Scene: Central Perk, Rachel is talking to a customer.]
# [Scene: Central Perk, Monica enters with some mail.]
# [Scene: Monica and Rachel's, Rachel and Ross are eating Chinese.]
# [Scene: Joe-G's Pizza, the guys are there.]
# [Scene: Monica and Rachel's, Rachel is taking care of Marcel and they are watching a
# soap opera.]
# [Scene: Monica and Rachel's, continued from earlier.]
# [Scene: Monica and Rachel's. Rachel and Ross are there. Ross is trying to get the dress
# off Marcel.]
# [Scene: Central Perk, Monica, Joey, Phoebe, and Chandler are looking through Monica's
# high school yearbook]
# [Scene: Monica and Rachel's, everyone is there.]
# [Scene: Central Perk, everyone but Rachel is there.]
# [Scene: Barry's Office, the post-coital Barry and Rachel are recovering on the chair.]
# [Scene: Monica and Rachel's, everyone is there except Rachel.]
# [Scene: Barry's Office, Rachel and Barry are getting dressed.]
# [Scene: Monica and Rachel's, Chandler enters clutching his phone.]
# [Scene: Monica and Rachel's, the next morning.  Chandler is sitting and staring at
# his phone.  Monica enters and creeps up next to Chandler.]
# [Scene: Central Perk, Rachel is serving coffee as Mindy enters.]
# [Scene: Monica and Rachel's, Phoebe and Ross are doing a crossword, Monica is cooking,
# and Chandler is still staring at his phone.]
# [Scene: Barry's Office, Barry is preparing his tools alone as Rachel enters.]
# [Scene: Monica and Rachel's, Monica and Rachel are there.]
# [Scene: Central Perk, everyone is there.]
# [Scene: Monica and Rachel's, everyone is looking at papers.]
# [Scene: Monica and Rachel's, late at night Monica is still examining her bill as Rachel
# emerges from her room.]
# [Scene: Central Perk, Joey and Chandler are discussing stage names.]
# [Scene: Monica and Rachel's, Monica is there as Phoebe and Rachel enter.]
# [Scene: A Tap Class, the girls are standing at the door.]
# [Scene: Central Perk, Ross is entering.]
# [Scene: Central Perk, scene continued from earlier.  They guys are sitting there
# like the Three Monkeys.]
# [Scene: Monica and Rachel's, Monica, Rachel and Fake Monica are there.]
# [Scene: Monica and Rachel's, tiem lapse.  Everyone but Joey and Monica are there.]
# [Scene: Central Perk, Ross is talking to Dr. Baldhara, a zookeeper.]
# [Scene: Monica and Rachel's, Rachel is dusting. She comes to the table, lifts all the
# magazines and wipes under them, then just puts them down again. Monica bursts in,
# obviously drunk.]
# [Scene: New York City Department of Correction, Monica is visiting Fake Monica.]
# [Scene: Tap Class, Monica is standing by the door.]
# [Scene: The Airport, everyone but Monica is there to see off Marcel.]
# [Scene: A Theater, there is a casting session going on for a play.]
# Episode dialogue
# [Scene: Central Perk, continued from earlier, Chandler is sitting on the table.]
# [Scene: Chandler's office, he and Phoebe are there when the phone starts ringing.]
# [Scene: Monica and Rachel's, Monica and Rachel are there. Monica is just finishing
# cleaning the windows.]
# [Scene: Central Perk. Joey and Ross are there.]
# [Scene: Monica and Rachel's, Monica and Young Ethan are sitting in the couch.]
# [Scene: Monica's Bedroom, continued from earlier.]
# [Scene: Monica and Rachel's, everyone exept Monica is there.]
# [Scene: Chandler's office, he and Phoebe are taking a break from work.]
# [Scene: Central Perk. Everyone exept Phoebe and Chandler is there. Ross's beeper goes
# off and everyone exept him react.]
# [Scene: A hall on the floor where Chandler works. Chandler and Phoebe enters, and
# overhears some employees's conversation. One of them is doing Chandler.]
# [Scene: Monica and Rachel's, Ross is watching TV, but turns it off, and Rachel is
# sleeping on the couch. Ross puts a blanket over her.]
# [Scene: The Hallway, Ross is eagerly waiting for the others to get ready, to go to the
# hospital.]
# [Scene: The hospital, Ross, Rachel, Chandler, Joey, and Monica are in the waiting room,
# waiting for Carol and Susan to arrive.]
# [Scene: Carol's Hospital Room, Carol is on the bed, Ross and Susan are at her side.]
# [Scene: The Waiting Room, Chandler is falling asleep on Monica's shoulder.]
# [Scene: The Waiting Room, Phoebe is playing a song. Chandler, Monica, and Ross are
# there as well.]
# [Scene: Joey and Lydia in the hospital room. Lydia is on the phone with her mother.]
# [Scene: Carol's Hospital Room, Ross and Susan are coaching Carol.]
# [Scene: Lydia's Hospital Room, Joey is helping Lydia go through labor, a nurse is now
# present in her room as well.]
# [Scene: The Hall, Ross and Susan are arguing.]
# [Scene: The Broom Closet, Ross and Susan are trying to get out.]
# [Scene: Carol's room, Rachel and Dr. Franzblau are there with her.]
# [Scene: Lydia's Room, Joey is helping her deliver.]
# [Scene: The Broom Closet, Ross has picked up a vacuum and is holding it at the door.]
# [Scene: The Waiting Room, Monica is on the phone with her mother, Chandler is standing
# behind her.]
# [Scene: The Waiting Room, Rachel and Dr. Franzblau have gone to get coffee.]
# [Scene: The Hall Outside Lydia's Room, Joey is walking up to Lydia's room with
# balloons, but before he enters he sees that the baby's father has arrived. He listens at
# the door.]
# [Scene: The Broom Closet, Ross is trying to open the door with a credit card, with no
# success.]
# [Scene: Carol's Room, she is ready to give birth. Everyone is there except for Phoebe,
# Ross, and Susan, who are in the broom closet.]
# [Scene: The Broom Closet, Ross has used a broom to open the air vent in the ceiling.
# Phoebe is wearing a janitor's uniform, ready to go up in the vent.]
# [Scene: Carol's Room, Ross and Susan rush in.]
# [Scene: The Delivery Room, Carol is holding the infant.]
# [Scene: The Hospital, the camera is placed as though it were Ben's eyes.]
# [Scene: Central Perk, the whole gang is there, Ross is showing pictures of his new baby
# boy, Ben, to the group.]
# [Scene: Monica and Rachel's, Monica and Phoebe are preparing for a barbecue for
# Rachel's birthday.]
# [Scene: Monica and Rachel's, continued from earlier.]
# [Scene: Airport, Ross has headphones on, and is listening to a 'How To Speak Chinese'
# tape. Occasionally, he makes an outburst in Chinese in accordance with the tape. He is
# getting on the jetway. The flight attendant is there.]
# [Scene: Joey's Bedroom, he and Melanie are in bed together.]
# [Scene: Monica and Rachel's, Monica, Phoebe, and Rachel are there. Monica is holding
# the wrapping paper from one of Rachel's gifts.]
# [Scene: Chandler and Joey's, Chandler is eating breakfast, Joey quietly opens his
# bedroom door.]
# [Scene: Monica and Rachel's, one week later. Monica is seated, Rachel comes out of her
# bedroom.]
# [Scene: Chandler and Joey's, Chandler is seated, and the apartment is filled with
# baskets of fruit. Joey enters, check in hand.]
# [Scene: Monica and Rachel's Balcony, Rachel is having drinks with her date, Carl.]
# [Scene: Airport. Madonna's Take A Bow plays in the background as Rachel waits at
# the gate with flowers.]

# %%
annotated_timestamps = pd.read_excel(Path("./Friends Location.xlsx"))
annotated_timestamps["idx"] = annotated_timestamps["idx"].apply(lambda x: str(x).strip().zfill(4))
annotated_timestamps
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 annotated_timestamps = pd.read_excel(Path("./Friends Location.xlsx"))
#       2 annotated_timestamps["idx"] = annotated_timestamps["idx"].apply(lambda x: str(x).strip().zfill(4))
#       3 annotated_timestamps
#
# File ~/anaconda3/envs/mllm_episodic/lib/python3.12/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~/anaconda3/envs/mllm_episodic/lib/python3.12/site-packages/pandas/io/excel/_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File ~/anaconda3/envs/mllm_episodic/lib/python3.12/site-packages/pandas/io/excel/_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File ~/anaconda3/envs/mllm_episodic/lib/python3.12/site-packages/pandas/io/common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)    878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Friends Location.xlsx'
